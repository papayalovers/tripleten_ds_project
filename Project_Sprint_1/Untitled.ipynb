# %%
import pandas as pd

df = pd.read_csv('music_project_en.csv')

df.head(5)
# Out:
#      userID                        Track            artist  genre  \
# 0  FFB692EC            Kamigata To Boots  The Mass Missile   rock
# 1  55204538  Delayed Because of Accident  Andreas Rönnberg   rock
# 2    20EC38            Funiculì funiculà       Mario Lanza    pop
# 3  A3DD03C9        Dragons in the Sunset        Fire + Ice   folk
# 4  E2DC1FAE                  Soul People        Space Echo  dance
#
#         City        time        Day
# 0  Shelbyville  20:28:33  Wednesday
# 1  Springfield  14:07:09     Friday
# 2  Shelbyville  20:58:07  Wednesday
# 3  Shelbyville  08:37:09     Monday
# 4  Springfield  08:34:34     Monday

# %%
df = df.rename(columns={
    '  userID' : 'user_id',
    'Track' : 'track',
    '  City  ' : 'city',
    'Day': 'day',
})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65079 entries, 0 to 65078
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  65079 non-null  object
#  1   track    63736 non-null  object
#  2   artist   57512 non-null  object
#  3   genre    63881 non-null  object
#  4   city     65079 non-null  object
#  5   time     65079 non-null  object
#  6   day      65079 non-null  object
# dtypes: object(7)
# memory usage: 3.5+ MB

# %%
# menerapkan loop terhadap nama-nama kolom dan menggganti nilai yang hilang dengan 'unknown'
columns_to_replace = ['track', 'artist', 'genre']

for column in columns_to_replace: 
    if column in df:
        df[column] = df[column].fillna('unknown')

# %%
print(df.columns)
# Out:
# Index(['user_id', 'track', 'artist', 'genre', 'city', 'time', 'day'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65079 entries, 0 to 65078
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  65079 non-null  object
#  1   track    65079 non-null  object
#  2   artist   65079 non-null  object
#  3   genre    65079 non-null  object
#  4   city     65079 non-null  object
#  5   time     65079 non-null  object
#  6   day      65079 non-null  object
# dtypes: object(7)
# memory usage: 3.5+ MB

# %%
df_duplicated = df[df.duplicated()]

df.duplicated().sum()
# Out:
# 3826

# %%
# menampilkan nama genre yang unik
genre_sorted = sorted(df['genre'].unique())
genre_sorted
# Out:
# ['acid',
#  'acoustic',
#  'action',
#  'adult',
#  'africa',
#  'afrikaans',
#  'alternative',
#  'ambient',
#  'americana',
#  'animated',
#  'anime',
#  'arabesk',
#  'arabic',
#  'arena',
#  'argentinetango',
#  'art',
#  'audiobook',
#  'avantgarde',
#  'axé',
#  'baile',
#  'balkan',
#  'beats',
#  'bigroom',
#  'black',
#  'bluegrass',
#  'blues',
#  'bollywood',
#  'bossa',
#  'brazilian',
#  'breakbeat',
#  'breaks',
#  'broadway',
#  'cantautori',
#  'cantopop',
#  'canzone',
#  'caribbean',
#  'caucasian',
#  'celtic',
#  'chamber',
#  'children',
#  'chill',
#  'chinese',
#  'choral',
#  'christian',
#  'christmas',
#  'classical',
#  'classicmetal',
#  'club',
#  'colombian',
#  'comedy',
#  'conjazz',
#  'contemporary',
#  'country',
#  'cuban',
#  'dance',
#  'dancehall',
#  'dancepop',
#  'dark',
#  'death',
#  'deep',
#  'deutschrock',
#  'deutschspr',
#  'dirty',
#  'disco',
#  'dnb',
#  'documentary',
#  'downbeat',
#  'downtempo',
#  'drum',
#  'dub',
# ...

# %%
# masukkan fungsi yang mengganti duplikat implisit

def replace_wrong_genres(wrong_genres, correct_genre):
    for wrong_genres in wrong_genres: #looping untuk setiap genre yang salah
        df['genre'] = df['genre'].replace(wrong_genres, correct_genre) #setiap nama yang salah akan di replace
        
incorrect = ['hip','hip-hop','hop']
correct = 'hiphop' #value yang benar

replace_wrong_genres(incorrect,correct)

# %%
sorted(df['genre'].unique())
# Out:
# ['acid',
#  'acoustic',
#  'action',
#  'adult',
#  'africa',
#  'afrikaans',
#  'alternative',
#  'ambient',
#  'americana',
#  'animated',
#  'anime',
#  'arabesk',
#  'arabic',
#  'arena',
#  'argentinetango',
#  'art',
#  'audiobook',
#  'avantgarde',
#  'axé',
#  'baile',
#  'balkan',
#  'beats',
#  'bigroom',
#  'black',
#  'bluegrass',
#  'blues',
#  'bollywood',
#  'bossa',
#  'brazilian',
#  'breakbeat',
#  'breaks',
#  'broadway',
#  'cantautori',
#  'cantopop',
#  'canzone',
#  'caribbean',
#  'caucasian',
#  'celtic',
#  'chamber',
#  'children',
#  'chill',
#  'chinese',
#  'choral',
#  'christian',
#  'christmas',
#  'classical',
#  'classicmetal',
#  'club',
#  'colombian',
#  'comedy',
#  'conjazz',
#  'contemporary',
#  'country',
#  'cuban',
#  'dance',
#  'dancehall',
#  'dancepop',
#  'dark',
#  'death',
#  'deep',
#  'deutschrock',
#  'deutschspr',
#  'dirty',
#  'disco',
#  'dnb',
#  'documentary',
#  'downbeat',
#  'downtempo',
#  'drum',
#  'dub',
# ...

# %%
track_list = len(df)

# %%
print(track_list)
# Out:
# 65079

# %%
# masukkan fungsi yang mengganti duplikat implisit

def replace_wrong_genres(wrong_genres, correct_genre):
    for wrong_genres in wrong_genres: #looping untuk setiap genre yang salah
        df['genre'] = df['genre'].replace(wrong_genres, correct_genre) #setiap nama yang salah akan di replace
        
incorrect = ['hip','hip-hop','hop']
correct = 'hiphop' #value yang benar

# %%
def number_tracks(day, city):
    track_list = df[df[day] == city]

# %%
print(number_tracks('Monday','Springfield'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Monday'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 print(number_tracks('Monday','Springfield'))
#
# ...
